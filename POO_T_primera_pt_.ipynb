# %% [markdown]
# ## Tarea 1. Primera parte.

# %%
import random

# %%
import numpy as np

# %%
import pandas as pd

# %%
# para las graficas
import matplotlib.pyplot as plt
from pylab import plot

# %% [markdown]
# ---
#
#
# 1. Genera una lista que consista de  20  números que estén en el intervalo  [−1,1] . Llámala Lista_1.

# %%
lista_1=[random.uniform(-1, 1,)for _ in range(20)]
lista_1
# Out:
# [0.08907405697456361,
#  0.8139041320449387,
#  -0.8814193795312075,
#  -0.03739341988182332,
#  0.22613505576448079,
#  0.39860662101240685,
#  0.5654121914298096,
#  0.6955061759423544,
#  0.7757529775421581,
#  -0.4668895451500108,
#  0.9789442994299067,
#  -0.14404600821953872,
#  -0.5925358586239191,
#  0.11079040911339288,
#  -0.3667326868970464,
#  0.3866123901238263,
#  0.836566187567332,
#  0.7450048514798047,
#  -0.08223629389834963,
#  0.8405985802154703]

# %% [markdown]
# ---
#
#
# 2. Genera una lista que consista de  20  números que sean enteros en el intervalo  [1500,3000] . Llámala Lista_2.

# %%
lista_2=[random.randint(1500,3000)for _ in range(20)]
lista_2
# Out:
# [2868,
#  2124,
#  1563,
#  2715,
#  2649,
#  1695,
#  1932,
#  2823,
#  2281,
#  1870,
#  2037,
#  1701,
#  2623,
#  1976,
#  2472,
#  2515,
#  2993,
#  2291,
#  2354,
#  1942]

# %%
lista_2a=[np.random.randint(1500,3000,20)]
lista_2a
# Out:
# [array([2538, 2868, 1584, 2164, 1948, 1829, 2192, 2330, 2702, 2730, 2484,
#         2472, 2803, 1614, 1833, 1546, 2000, 2613, 2650, 2719])]

# %% [markdown]
# ---
#
#
# 3. Crea un diccionario cuyas llaves sean "CapSmall" y "CapLarge" y sus valores sean la Lista_1 y Lista_2, respectivamente.

# %%
Caps= {"CapSmall":lista_1,"CapLarge":lista_2}
Caps
# Out:
# {'CapSmall': [0.08907405697456361,
#   0.8139041320449387,
#   -0.8814193795312075,
#   -0.03739341988182332,
#   0.22613505576448079,
#   0.39860662101240685,
#   0.5654121914298096,
#   0.6955061759423544,
#   0.7757529775421581,
#   -0.4668895451500108,
#   0.9789442994299067,
#   -0.14404600821953872,
#   -0.5925358586239191,
#   0.11079040911339288,
#   -0.3667326868970464,
#   0.3866123901238263,
#   0.836566187567332,
#   0.7450048514798047,
#   -0.08223629389834963,
#   0.8405985802154703],
#  'CapLarge': [2868,
#   2124,
#   1563,
#   2715,
#   2649,
#   1695,
#   1932,
#   2823,
#   2281,
#   1870,
#   2037,
#   1701,
#   2623,
#   1976,
#   2472,
#   2515,
#   2993,
#   2291,
#   2354,
#   1942]}

# %%
type(Caps)
# Out:
# dict

# %% [markdown]
# ---
#
#
# 4. Crea un DataFrame a partir del diccionario del punto anterior. Llámalo df.

# %%
df=pd.DataFrame(Caps)
df
# Out:
#     CapSmall  CapLarge
# 0   0.089074      2868
# 1   0.813904      2124
# 2  -0.881419      1563
# 3  -0.037393      2715
# 4   0.226135      2649
# 5   0.398607      1695
# 6   0.565412      1932
# 7   0.695506      2823
# 8   0.775753      2281
# 9  -0.466890      1870
# 10  0.978944      2037
# 11 -0.144046      1701
# 12 -0.592536      2623
# 13  0.110790      1976
# 14 -0.366733      2472
# 15  0.386612      2515
# 16  0.836566      2993
# 17  0.745005      2291
# 18 -0.082236      2354
# 19  0.840599      1942

# %% [markdown]
# ---
# 5. Reindexa los índices poniendo Año 1 ,...,  Año 20.

# %%
df=pd.DataFrame(Caps, index=[f"Año {i+1}" for i in range(20)])
df
# Out:
#         CapSmall  CapLarge
# Año 1   0.089074      2868
# Año 2   0.813904      2124
# Año 3  -0.881419      1563
# Año 4  -0.037393      2715
# Año 5   0.226135      2649
# Año 6   0.398607      1695
# Año 7   0.565412      1932
# Año 8   0.695506      2823
# Año 9   0.775753      2281
# Año 10 -0.466890      1870
# Año 11  0.978944      2037
# Año 12 -0.144046      1701
# Año 13 -0.592536      2623
# Año 14  0.110790      1976
# Año 15 -0.366733      2472
# Año 16  0.386612      2515
# Año 17  0.836566      2993
# Año 18  0.745005      2291
# Año 19 -0.082236      2354
# Año 20  0.840599      1942

# %% [markdown]
# ---
# 6. Realiza una explicación de la estadística descriptiva de tu DataFrame.

# %%
df.describe()
# Out:
#         CapSmall     CapLarge
# count  20.000000    20.000000
# mean    0.244583  2271.200000
# std     0.546768   426.672511
# min    -0.881419  1563.000000
# 25%    -0.097689  1939.500000
# 50%     0.306374  2286.000000
# 75%     0.752692  2629.500000
# max     0.978944  2993.000000

# %% [markdown]
# ---
# 7. ¿Cuál es el valor mínimo de la columna "CapSmall"?

# %%
valor_min_CapSmall = df["CapSmall"].min()
print("El valor mínimo en la columna /CapSmall/ es:", valor_min_CapSmall)
# Out:
# El valor mínimo en la columna /CapSmall/ es: -0.8814193795312075

# %% [markdown]
# ---
#
#
# 8. ¿Cuál es "CapLarge" promedio del año 10 al año 20?

# %%
df_CL=df.drop(columns=["CapSmall"])
df10_20=df_CL.iloc[9:20]
print(df10_20)

promedio_CapLarge = df10_20["CapLarge"].mean()
print("El promedio de la Columna /CapLarge/ del año 10 al 20 es:", promedio_CapLarge)
# Out:
#         CapLarge
# Año 10      1870
# Año 11      2037
# Año 12      1701
# Año 13      2623
# Año 14      1976
# Año 15      2472
# Año 16      2515
# Año 17      2993
# Año 18      2291
# Año 19      2354
# Año 20      1942
# El promedio de la Columna /CapLarge/ del año 10 al 20 es: 2252.181818181818

# %% [markdown]
# ---
#
#
# 9. Realiza una gráfica de Año contra "CapLarge".

# %%
df["CapLarge"].plot(label="df", figsize=(14,6))
# Out:
# <Axes: >

# %% [markdown]
# ---
#
#
# 10. Muestra el DataFrame que obtienes si tomas aquellos valores de "CapLarge" mayores a  2000 . ¿Cuál es la dimensión (shape) de tu nueva base de datos?

# %%
df_filtro= df_CL[df_CL["CapLarge"] > 2000]
df_filtro
# Out:
#         CapLarge
# Año 1       2868
# Año 2       2124
# Año 4       2715
# Año 5       2649
# Año 8       2823
# Año 9       2281
# Año 11      2037
# Año 13      2623
# Año 15      2472
# Año 16      2515
# Año 17      2993
# Año 18      2291
# Año 19      2354

# %%
df_filtro.shape
# Out:
# (20, 1)
